# %% [markdown]
# Python Operators

# %% [markdown]
# Arithmetic Operators

# %%
# Variables
a = 15
b = 4

# Addition
print("Addition:", a + b)  

# Subtraction
print("Subtraction:", a - b) 

# Multiplication
print("Multiplication:", a * b)  

# Division
print("Division:", a / b) 

# Floor Division
print("Floor Division:", a // b)  

# Modulus
print("Modulus:", a % b) 

# Exponentiation
print("Exponentiation:", a ** b)
# Out:
# Addition: 19
# Subtraction: 11
# Multiplication: 60
# Division: 3.75
# Floor Division: 3
# Modulus: 3
# Exponentiation: 50625

# %% [markdown]
# comparision operator :

# %%
a = 13
b = 33

print(a > b)
print(a < b)
print(a == b)
print(a != b)
print(a >= b)
print(a <= b)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# Logical Operator

# %%
a = True
b = False
print(a and b)
print(a or b)
print(not a)
# Out:
# False
# True
# False

# %%
store=int(input("Enter the number"))
store1=int(input("Enter the number"))
if store and store1 ==store+store1:
    print("it is correct")
else:
    print("not correct")
# Out:
# not correct

# %%
x = 24
y = 20
list = [10, 20, 30, 40, 50]

if (x not in list):
    print("x is NOT present in given list")
else:
    print("x is present in given list")

if (y in list):
    print("y is present in given list")
else:
    print("y is NOT present in given list")
# Out:
# x is NOT present in given list
# y is present in given list

# %% [markdown]
# Input: arr[] = [1, 2, 3, 7, 5], target = 12
# Output: [2, 4]
# Explanation: The sum of elements from 2nd to 4th position is 12.

# %%
arr=[1,2,3,4,6,6]
target=12
point=0
point1=0
count=0
count=0
for i in range(len(arr)):
    point=i
    
    point1=i+1
    if point+point1==target:
        print(arr[i])
        
    else:
        print("nothing")
# Out:
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing

# %%
def trouble(j_angry,s_angry):
    if j_angry and s_angry:
        return True
    else:
        return False

j_angry=True
s-angry=False
# Out:
#   Cell In[13], line 6
#     s-angry=False
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
a = int(input("enter an number"))
for i in range():
    if i==a:
        print(i)
        continue
    else:
        print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a = int(input("enter an number"))
#       2 for i in range():
#       3     if i==a:
#
# ValueError: invalid literal for int() with base 10: 'as'

# %%
print(type(10/2)) 
bool(0)
len([1,2,[3,4]])
print(3 > 2 and 2 > 5)
[1,2,3]*2 
print(type({}))
range(3)
# Out:
# <class 'float'>
# False
# <class 'dict'>
# range(0, 3)

# %%
x = 5
y = True
print(x + y)
# Out:
# 6

# %%
a=10
b=10
print(id(a)==id(b))
# Out:
# True

# %%
List=[1,2,3,4,5,4,3,2,1]
List.pop(3)
print(List)
# Out:
# [1, 2, 3, 5, 4, 3, 2, 1]

# %%
x = "10"
y = 5
print(x * y)
# Out:
# 1010101010
